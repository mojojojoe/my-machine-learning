# %%
import ffn as fin
import pandas as pd
import math as m

# %%
prices = fin.get('QQQ',start = '2008-01-01').dropna().rebase()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
ax = prices.plot(figsize = (10,5))

# %%
reQQQ = prices.to_returns().dropna()

# %%
reQQQ.head()
# Out:
#                  qqq
# Date
# 2008-01-03  0.004166
# 2008-01-04 -0.043856
# 2008-01-07 -0.004752
# 2008-01-08 -0.025949
# 2008-01-09  0.021313

# %%
re36O = pd.read_csv('resources/serialized_returns.csv',delimiter=' ')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 re36O = pd.read_csv('resources/serialized_returns.csv',delimiter=' ')
#
# File ~/.local/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
re36Odf = pd.DataFrame(re36O)
re36Odf

# %%
idx = re36Odf["Date"]
re36Odf["Date"].drop()
re36Odf

# %%
pi36O = re36O.to_price_index()
piQQQ = reQQQ.to_price_index()
pi36O

# %%
[,lgkgggbbbreQQQ.hist(figsize=(10,5))
re36O.hist(figsize=(10,5))

# %%
prices.calc_stats().display()

# %%
log_prices = prices.map(math.log)

# %%
log_prices.plot()

# %%
log_prices.calc_stats().display()
